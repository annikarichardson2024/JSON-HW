# %% [markdown]
# <a href="https://colab.research.google.com/github/annikarichardson2024/JSON-HW/blob/main/JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyMySQL
# !pip install mysql-connector-python
# !pip install sqlalchemy
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json

# %%
json_data = ("https://raw.githubusercontent.com/annikarichardson2024/JSON-HW/main/coll%20bb_SortByConf.json")

# %%
import pandas as pd
import json

#df = json.loads(json_data) <- idk why these were not working


df = pd.read_json(json_data)
df = pd.DataFrame(df)
df.head(100)
# Out:
#                                                 teams
# 0   {'tid': 159, 'cid': 0, 'did': 0, 'region': 'Bo...
# 1   {'tid': 105, 'cid': 0, 'did': 0, 'region': 'Cl...
# 2   {'tid': 109, 'cid': 0, 'did': 0, 'region': 'Fl...
# 3   {'tid': 18, 'cid': 0, 'did': 0, 'region': 'Lou...
# 4   {'tid': 31, 'cid': 0, 'did': 0, 'region': 'Nor...
# ..                                                ...
# 95  {'tid': 300, 'cid': 5, 'did': 11, 'region': 'J...
# 96  {'tid': 72, 'cid': 6, 'did': 12, 'region': 'Ea...
# 97  {'tid': 139, 'cid': 6, 'did': 12, 'region': 'S...
# 98  {'tid': 239, 'cid': 6, 'did': 12, 'region': 'N...
# 99  {'tid': 266, 'cid': 6, 'did': 12, 'region': 'I...
#
# [100 rows x 1 columns]

# %%
# QUESTION 1
print(df.count())
# Out:
# teams    320
# dtype: int64

# %%
# QUESTION 2

virginia_count = df['state'].count() # I am confused by this error. It seems like this is definetly a solution that should work
print(virginia_count)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# QUESTION 3
import os
import pymysql

for row in df:
     if df['name'].unique:
          print()
     else:
          print(row)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
